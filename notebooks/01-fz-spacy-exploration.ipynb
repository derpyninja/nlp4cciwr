# %% [markdown]
# # Explore **spacy** package
# Felix Zaussinger | 06.01.2021
#
# ## Core Analysis Goal(s)
# 1. Discover core functionalities of spacy library
# 2. Test pre-processing chains on example documents from BBC Monitoring
# 3. Test simple models
#
# ## Key Insight(s)
# 1.
# 2.
# 3.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import logging
from pathlib import Path
import numpy as np
import scipy as sp
import statsmodels.api as sm
from statsmodels.formula.api import ols
import glob
import os
import spacy
import re
import pandas as pd
import numpy as np
import gensim
from gensim.utils import simple_preprocess
import gensim.corpora as corpora
from pprint import pprint
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (16, 9.)})
sns.set_style("ticks")

import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

logging.basicConfig(level=logging.INFO, stream=sys.stdout)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Define directory structure

# %%
# project directory
abspath = os.path.abspath('')
project_dir = str(Path(abspath).parents[0])

# sub-directories
data_raw = os.path.join(project_dir, "data", "raw")
data_interim = os.path.join(project_dir, "data", "interim")
data_processed = os.path.join(project_dir, "data", "processed")
figure_dir = os.path.join(project_dir, "plots")

# %% [markdown]
# Code ...

# %%
# init language object
nlp = spacy.load('en_core_web_lg')

# %%
# build file list
dp_string = os.path.join(data_raw, "BBC_2007_07_04_TXT", "*.txt")
file_list = glob.glob(dp_string)
file_list = sorted(file_list)

# read text
n = 5
corpus = []
for file_path in file_list[:n]:
    with open(file_path) as f_input:

        # read
        text = f_input.read()

        # remove new lines
        text = re.sub('\s+', ' ', text)

        # remove urls
        text = re.sub(r'http\S+', '', text)

        # remove non-letter chars
        text = re.sub('[^a-zA-Z]', ' ', text)

        # remove single quotes
        text = re.sub("\'", '', text)

        #append
        corpus.append(text)

# %% [markdown]
# https://gist.github.com/SandieIJ/69fc80c372e823fecfd4eeeda2156936

# %%
#break down sentences into words
def sent_to_words(sentences):
    for sentence in sentences:
        yield gensim.utils.simple_preprocess(str(sentence), deacc=True, min_len=2, max_len=15)

doc = corpus[0]

# tokenize
data_words = list(sent_to_words(doc))

# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100)
trigram = gensim.models.Phrases(bigram[doc], threshold=100)

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

def make_bigrams(texts):
    return [bigram_mod[text] for text in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[text]] for text in texts]

# Form Bigrams
data_words_bigrams = make_bigrams(data_words)
# Out:
# INFO:gensim.models.phrases:collecting all words and their counts
# INFO:gensim.models.phrases:PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO:gensim.models.phrases:collected 0 word types from a corpus of 0 words (unigram + bigrams) and 3878 sentences
# INFO:gensim.models.phrases:using 0 counts as vocab in Phrases<0 vocab, min_count=5, threshold=100, max_vocab_size=40000000>
# INFO:gensim.models.phrases:collecting all words and their counts
# INFO:gensim.models.phrases:PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO:gensim.models.phrases:collected 49 word types from a corpus of 3878 words (unigram + bigrams) and 3878 sentences
# INFO:gensim.models.phrases:using 49 counts as vocab in Phrases<0 vocab, min_count=5, threshold=100, max_vocab_size=40000000>
# INFO:gensim.models.phrases:source_vocab length 0
# INFO:gensim.models.phrases:Phraser built with 0 phrasegrams
# INFO:gensim.models.phrases:source_vocab length 49
# INFO:gensim.models.phrases:Phraser built with 0 phrasegrams

# %%
len(data_words_bigrams)
# Out:
# 3878

# %%
# %%time
doc = nlp(corpus[0])
for doc in nlp.pipe(corpus, disable=["tagger", "parser"]):
    # Do something with the doc here
    print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# [('Nigeria', 'GPE'), ('Pan-Niger Delta', 'NORP'), ('Akpa Esajere', 'PERSON'), ('Federalism Tops Talks As Pan-Niger Delta Summit Begins', 'WORK_OF_ART'), ('Nigerian', 'NORP'), ('Guardian', 'ORG'), ('20 October', 'DATE'), ('100 per cent', 'MONEY'), ('yesterday', 'DATE'), ('first', 'ORDINAL'), ('Pan-Niger Delta', 'ORG'), ('Calabar', 'GPE'), ('Expectedly', 'ORDINAL'), ('University of Calabar', 'ORG'), ('100 per cent', 'MONEY'), ('six', 'CARDINAL'), ('the First Republic', 'GPE'), ('Ethnic Nationality Forum', 'ORG'), ('the Niger Delta Area', 'LOC'), ('David Dafinone', 'PERSON'), ('100 per cent', 'MONEY'), ('Cross River', 'LOC'), ('Donald Duke', 'PERSON'), ('Tony Momoh', 'PERSON'), ('Bayelsa Traditional Rulers', 'ORG'), ('Raph Iwowari Mein VII', 'PERSON'), ('Margaret Ekpo', 'PERSON'), ('OMPADEC', 'ORG'), ('Albert Horsfall', 'PERSON'), ('Federal House of Representative', 'ORG'), ('Nduese Essien', 'PERSON'), ('ECOMOG', 'ORG'), ('Maj-Gen Felix Mujakper', 'PERSON'), ('First', 'ORDINAL'), ('Mfio Akobo', 'PERSON'), ('Willie Okowa', 'PERSON'), ('Bishop Uses', 'PERSON'), ('Ikot Ekpene Diocese', 'ORG'), ('Dafinone', 'ORG'), ('the Niger Delta', 'LOC'), ('the years', 'DATE'), ('first', 'ORDINAL'), ('four', 'CARDINAL'), ('all-season', 'DATE'), ('Benin', 'GPE'), ('Akwa Ibom', 'GPE'), ('the Land Use Act 1978', 'LAW'), ('the Petroleum Act 1969', 'LAW'), ('Land Title Vesting Decree', 'LAW'), ('1993', 'DATE'), ('National Inland Waterways Authority', 'ORG'), ('1997', 'DATE'), ('the Mineral Act', 'LAW'), ('the Niger Delta', 'LOC'), ('Dafinone', 'ORG'), ('Obafemi Awolowo', 'PERSON'), ('Nnamdi Azikiwe', 'PERSON'), ('Sardauna', 'PERSON'), ('Sokoto', 'GPE'), ('Clement Isong', 'PERSON'), ('Omo-Osagie', 'PERSON'), ('Ken Saro-Wiva', 'PERSON'), ('Nigeria', 'GPE'), ('today', 'DATE'), ('Guardian', 'ORG'), ('Lagos', 'GPE'), ('English', 'LANGUAGE'), ('20 Oct 01\u2028\u2028BBC Mon', 'DATE'), ('© British Broadcasting Corporation', 'ORG'), ('2001', 'DATE')]
# [('Brazil', 'GPE'), ('Amazon', 'ORG'), ('Brazil', 'GPE'), ('Amazon', 'ORG'), ('Brazilian', 'NORP'), ('EstadoPorto Alegre', 'ORG'), ('2nd April', 'DATE'), ('the Rio Grande', 'ORG'), ('Sul Federal Court', 'ORG'), ('the Amazon Region Surveillance System', 'ORG'), ('Sivam', 'PERSON'), ('the Aeronautics Ministry', 'ORG'), ('Edgard Antonio Lippmann Junior', 'PERSON'), ('the Fourth Regional Federal Court', 'FAC'), ('Porto Alegre', 'GPE'), ('31st March', 'DATE'), ('Spanish', 'NORP'), ('recurso em acao', 'PERSON'), ('Thomaz Raymond Korontai', 'PERSON'), ('Parana State', 'GPE'), ('Sivam', 'PERSON'), ('the National Accounting Office', 'ORG'), ('TCU', 'ORG'), ('Lippmann', 'PERSON'), ('Sivam', 'ORG'), ('US', 'GPE'), ('Raytheon', 'ORG'), ('Brazilian', 'NORP'), ('ESCA', 'ORG'), ('Control Systems Engineering', 'ORG'), ('Raytheon', 'ORG'), ('Social Security', 'ORG'), ('1st April', 'DATE'), ('this evening', 'TIME'), ('Planalto Palace', 'FAC'), ('Brasilia', 'GPE'), ('Agencia Estado', 'ORG'), ('Sao Paulo', 'GPE'), ('Portuguese', 'NORP'), ('British Broadcasting Corporation', 'ORG'), ('1997', 'DATE'), ('Peruvian', 'NORP'), ('Ecuador', 'GPE'), ('Amazon', 'ORG'), ('Mexican', 'NORP'), ('Notimex', 'PERSON'), ('Lima', 'GPE'), ('9th October', 'DATE'), ('Peru', 'GPE'), ('Ecuador', 'GPE'), ('the Amazon River', 'LOC'), ('Eduardo Ferrero Costa', 'PERSON'), ('today', 'DATE'), ('Ecuador', 'GPE'), ('Maranon', 'ORG'), ('Amazon Rivers', 'ORG'), ('1942', 'DATE'), ('the Rio de Janeiro Protocol', 'EVENT'), ('Peru', 'GPE'), ('Ecuador', 'GPE'), ('Peruvian', 'NORP'), ('this afternoon', 'TIME'), ('Ferrero Costa', 'PERSON'), ('Ecuador', 'GPE'), ('Argentina', 'GPE'), ('Brazil', 'GPE'), ('Chile', 'GPE'), ('the United States', 'GPE'), ('Santiago', 'GPE'), ('Brasilia', 'GPE'), ('Ecuador', 'GPE'), ('Peruvian', 'NORP'), ('Peru', 'GPE'), ('Peru', 'GPE'), ('Andean', 'NORP'), ('1996', 'DATE'), ('Rio de Janeiro', 'GPE'), ('Ecuador', 'GPE'), ('Maranon', 'PRODUCT'), ('Amazon Rivers', 'ORG'), ('Ecuadoran', 'NORP'), ('Peru', 'GPE'), ('Horacio Sevilla', 'PERSON'), ('yesterday', 'DATE'), ('two', 'CARDINAL'), ('November', 'DATE'), ('Peruvian', 'NORP'), ('Alberto Fujimori', 'PERSON'), ('yesterday', 'DATE'), ('two', 'CARDINAL'), ('Peru', 'GPE'), ('Brasilia', 'GPE'), ('the last week of September', 'DATE'), ('two', 'CARDINAL'), ('first', 'ORDINAL'), ('from 24th to 28th November', 'DATE'), ('second', 'ORDINAL'), ('Peru', 'GPE'), ('Ferrero Costa', 'PERSON'), ('Peruvian', 'NORP'), ('second', 'ORDINAL'), ('the Rio de Janeiro', 'EVENT'), ('Notimex', 'PERSON'), ('Mexico City', 'GPE'), ('Spanish 1830', 'DATE'), ('© British Broadcasting Corporation', 'ORG'), ('1997', 'DATE'), ('http://www.bbcmonitoringonline.com/mmu?page=77&action=view&item=1&srchid=0025mrd&sw=1', 'WORK_OF_ART'), ('Brazilian', 'NORP'), ('Estado', 'GPE'), ('Brasilia', 'GPE'), ('14th October', 'DATE'), ('Iris Rezende', 'PERSON'), ('14th October', 'DATE'), ('Brazilian', 'NORP'), ('Barry McCaffrey', 'PERSON'), ('the US Office of National Drug Control Policy', 'ORG'), ('Rezende', 'PERSON'), ('Iris Rezende', 'PERSON'), ('McCaffrey', 'PERSON'), ('Amazon', 'ORG'), ('January', 'DATE'), ('Rezende', 'PERSON'), ('the United States', 'GPE'), ('Brazil', 'GPE'), ('Benedito Leonel', 'PERSON'), ('Brazil', 'GPE'), ('Leonel', 'PERSON'), ('Iris Rezende', 'PERSON'), ('Rezende', 'PERSON'), ('Leonel', 'PERSON'), ('Brazilian', 'NORP'), ('Bill Clinton', 'PERSON'), ('Justice', 'ORG'), ('Iris Rezende', 'PERSON'), ('Brazilian', 'NORP'), ('Rezende', 'PERSON'), ('Agencia Estado', 'ORG'), ('Sao Paulo', 'GPE'), ('Portuguese', 'NORP'), ('Oct 97\u2028\u2028BBC Mon', 'DATE'), ('© British Broadcasting Corporation', 'ORG'), ('France', 'GPE'), ('Federal Police', 'ORG'), ('Brazil', 'GPE'), ('France', 'GPE'), ('Brazilian', 'NORP'), ('26th', 'ORDINAL'), ('NovemberFrance', 'ORG'), ('Brazil', 'GPE'), ('420m dollars', 'MONEY'), ('the Federal Police', 'ORG'), ('Today', 'DATE'), ('Brazil', 'GPE'), ('Iris Rezende', 'PERSON'), ('French', 'NORP'), ('Jean-Pierre Chevenement', 'PERS ...
# [('Peru', 'GPE'), ('Peruvian', 'NORP'), ("newspaper'La", 'PERSON'), ('18th January', 'DATE'), ('years', 'DATE'), ('Roger Rumrill', 'PERSON'), ('one', 'CARDINAL'), ('the Programme to Counter Drugs', 'ORG'), ('Luis Ramas Puccio', 'PERSON'), ('Spanish', 'NORP'), ('Comision de Lucha Contra el', 'ORG'), ('Contradrogas', 'PERSON'), ('two', 'CARDINAL'), ('Contradrogas', 'PERSON'), ('27', 'CARDINAL'), ('1997', 'DATE'), ('18', 'CARDINAL'), ('1996', 'DATE'), ('40 per cent', 'MONEY'), ('1995', 'DATE'), ('50 per cent', 'MONEY'), ('the next five years', 'DATE'), ('100 per cent', 'MONEY'), ('a decade', 'DATE'), ('North American', 'NORP'), ('Andean', 'NORP'), ('hectares', 'CARDINAL'), ('Rumrill', 'PERSON'), ('the Andean Council of Coca Farmers', 'ORG'), ('1998-2002', 'DATE'), ('Contradrogas', 'ORG'), ('the past weeks', 'DATE'), ('1998', 'DATE'), ('1998-2002', 'DATE'), ('Contradrogas', 'PERSON'), ('Peruvian', 'NORP'), ('Contradrogas', 'PERSON'), ('45m dollars', 'MONEY'), ('107m dollars', 'MONEY'), ('US', 'GPE'), ('USAID', 'ORG'), ('the 22.6m dollars', 'FAC'), ('the UN Programme for International Drug Supervision', 'ORG'), ('Spanish', 'LANGUAGE'), ('Programa de las Naciones Unidas para la Fiscalizacion Internacional de Drogas]', 'ORG'), ('PNUFID', 'ORG'), ('the 1.1m dollars', 'FAC'), ('GTZ', 'ORG'), ('the German Cooperation Agency', 'ORG'), ('Contradrogas', 'PERSON'), ('Prompex', 'ORG'), ('11', 'CARDINAL'), ('14,450', 'CARDINAL'), ('Contradrogas', 'PERSON'), ('Banex', 'PERSON'), ('10m dollars', 'MONEY'), ('Rumrill', 'PERSON'), ('Rumrill', 'PERSON'), ('Contradrogas', 'PERSON'), ('the Presidency Ministry', 'ORG'), ('the Alto Huallaga Special Programme', 'ORG'), ('PEAH', 'PERSON'), ('the Central Huallaga', 'ORG'), ('Bajo Mayo Special Programme', 'ORG'), ('the Mountain Range-Central-Southern Special Programme', 'ORG'), ('the Madre de Dios Special Programme', 'PERSON'), ('several years', 'DATE'), ('Contradrogas', 'PERSON'), ('Rumrill', 'PERSON'), ('the Presidency Ministry', 'ORG'), ('the Programme to Fight Drugs', 'ORG'), ('the last two years', 'DATE'), ('Farmers', 'ORG'), ('Luis Lamas Puccio', 'PERSON'), ('Colombian', 'NORP'), ('Contradrogas', 'PERSON'), ('Contradrogas', 'PERSON'), ('Lamas', 'PERSON'), ('Peru', 'GPE'), ('Rumrill', 'PERSON'), ('Rumrill', 'PERSON'), ('Amazon', 'ORG'), ('English', 'LANGUAGE'), ('Pronaa', 'PERSON'), ('Lima', 'GPE'), ('Spanish', 'LANGUAGE'), ('18 Jan 98', 'DATE'), ('© British Broadcasting Corporation', 'ORG'), ('1998', 'DATE'), ('Peru', 'GPE'), ('Ecuadoran', 'GPE'), ("`El Comercio'", 'ORG'), ('20th January\n', 'DATE'), ('Fabian Alarcon', 'PERSON'), ('Ecuador', 'GPE'), ('Peru', 'GPE'), ('two', 'CARDINAL'), ('two', 'CARDINAL'), ('midday', 'TIME'), ('yesterday', 'DATE'), ('Carondelet Palace', 'FAC'), ('Alarcon', 'PERSON'), ('Ecuadoran', 'NORP'), ('Peruvian', 'NORP'), ('two', 'CARDINAL'), ('Alarcon', 'PERSON'), ('two', 'CARDINAL'), ('Ecuador', 'GPE'), ('Peru', 'GPE'), ('Brasilia', 'GPE'), ('99 per cent', 'MONEY'), ('Alarcon', 'PERSON'), ('four', 'CARDINAL'), ('third', 'ORDINAL'), ('two', 'CARDINAL'), ('two', 'CARDINAL'), ('three', 'CARDINAL'), ('the Amazon River', 'LOC'), ('the Amazon River', 'LOC'), ('the Amazon River', 'LOC'), ('Ecuador', 'GPE'), ('the Amazon River', 'LOC'), ("`El Comercio'", 'ORG'), ('Quito', 'GPE'), ('Spanish', 'LANGUAGE'), ('20 Jan 98', 'DATE'), ('© British Broadcasting Corporation', 'ORG'), ('1998', 'DATE'), ('Ecuador', 'GPE'), ('Peru', 'GPE'), ('Ecuadoran', 'GPE'), ('Peruvian', 'NORP'), ('Brazil', 'GPE'), ('19th January', 'DATE'), ('Ecuadoran', 'GPE'), ("`El Comercio'", 'ORG'), ('20th January', 'DATE'), ('Argentina', 'GPE'), ('Brazil', 'GPE'), ('Chile', 'GPE'), ('the United States', 'GPE'), ('1', 'CARDINAL'), ('Ecuador', 'GPE'), ('Peru', 'GPE'), ('1942', 'DATE'), ('Rio de Janeiro Peace', 'GPE'), ('1995', 'DATE'), ('Itamaraty Peace Declaration', 'EVENT'), ('Sign a Trade and Free Navigation Treaty', 'ORG'), ('Article 6 of the Rio de Janeiro Protocol', 'LAW'), ('Amazon', 'ORG'), ('the Amazon River', 'L ...
# [('Peru', 'GPE'), ('Fujimori', 'PERSON'), ('Peruvian', 'NORP'), ("La Republica'", 'ORG'), ('1st January', 'DATE'), ('Alberto Fujimori', 'PERSON'), ('yesterday', 'DATE'), ('microeconomy', 'ORG'), ('Fujimori', 'PERSON'), ('Nicolas Hermoza Rios', 'PERSON'), ('the Joint Command', 'ORG'), ('one', 'CARDINAL'), ('two', 'CARDINAL'), ('Fujimori', 'PERSON'), ('5 per cent', 'MONEY'), ('5.5 per cent', 'MONEY'), ('Peruvian', 'NORP'), ('the Council of Ministers', 'ORG'), ('Peruvian', 'NORP'), ('next year', 'DATE'), ('the Amazon Law', 'LAW'), ('Peru', 'GPE'), ('1998', 'DATE'), ('around 6.5 per cent', 'MONEY'), ('6.8 per cent', 'MONEY'), ('Hermoza Rios', 'PERSON'), ('Hermoza Rios', 'PERSON'), ('Washington', 'GPE'), ('approximately 30 days', 'DATE'), ('Mahuad', 'PERSON'), ('the Amazon Law', 'LAW'), ('the early hours of the morning', 'TIME'), ('Congress', 'ORG'), ('Sunday', 'DATE'), ('Brasilia', 'GPE'), ('second', 'ORDINAL'), ('Brazilian', 'NORP'), ('Fernando Henrique Cardoso', 'PERSON'), ('Monday', 'DATE'), ('Ecuadoran', 'NORP'), ('Jamil Mahuad', 'PERSON'), ('the Global Accord', 'LAW'), ("La Republica'", 'PERSON'), ('Lima', 'GPE'), ('Spanish', 'LANGUAGE'), ('1 Jan 99\u2028\u2028BBC Mon', 'DATE'), ('© British Broadcasting Corporation', 'ORG'), ('CIA', 'ORG'), ('Brazilian', 'NORP'), ('Estado', 'GPE'), ('Brasilia', 'GPE'), ('6th', 'ORDINAL'), ("`Carta Capital'", 'ORG'), ('Alberto Cardoso', 'PERSON'), ('6th May', 'DATE'), ('the US Central Intelligence Agency', 'ORG'), ('CIA', 'ORG'), ('Fernando Henrique Cardoso', 'PERSON'), ('Federal Police', 'ORG'), ('PT [Workers Party', 'ORG'), ('Justice', 'ORG'), ('Renan Calheiros', 'PERSON'), ('Luiz Felipe Lampreia', 'PERSON'), ('the Chamber of Deputies Defence Committee', 'ORG'), ('Jose Genoino', 'PERSON'), ('Sao Paulo', 'GPE'), ('Gen Cardoso', 'PERSON'), ('CIA', 'ORG'), ('Alberto Cardoso', 'PERSON'), ('CIA', 'ORG'), ('the Amazon Region Surveillance System', 'ORG'), ('Sivam', 'PERSON'), ('US', 'GPE'), ('Raytheon', 'ORG'), ('Gen Cardoso', 'PERSON'), ('Brazil', 'GPE'), ('Cardoso', 'PERSON'), ('Cardoso', 'PERSON'), ('PF', 'ORG'), ('the National Antidrug Secretariat', 'ORG'), ('Senad', 'PERSON'), ('Cardoso', 'PERSON'), ('Congressional Investigating Committee', 'ORG'), ('Cardoso', 'PERSON'), ('this week', 'DATE'), ('Cardoso', 'PERSON'), ('Senad', 'PERSON'), ('Gen Cardoso', 'PERSON'), ('PF', 'ORG'), ('Vicente Chelotti', 'PERSON'), ("Fernando Henrique Cardoso's", 'PERSON'), ('Gen Cardoso', 'PERSON'), ('Agencia Estado', 'ORG'), ('Sao Paulo', 'GPE'), ('Portuguese 1924', 'EVENT'), ('May 99\u2028\u2028BBC Mon LA1', 'DATE'), ('© British Broadcasting Corporation', 'ORG'), ('May 99\u2028\u2028', 'DATE'), ('NTV', 'ORG'), ('minutes', 'TIME'), ('Cienfuegos', 'GPE'), ('600', 'CARDINAL'), ('3.[02', 'CARDINAL'), ('Communists', 'NORP'), ('Mayari Municipality', 'GPE'), ('Politburo', 'ORG'), ('Jose Ramon Machado', 'PERSON'), ('Ventura', 'GPE'), ('First Party', 'ORG'), ('Jorge Luis Sierra Cruz', 'PERSON'), ('buro', 'ORG'), ('Machado Ventura', 'PERSON'), ('Sierra Cruz', 'PERSON'), ('Politburo', 'ORG'), ('4.[03', 'CARDINAL'), ('today', 'DATE'), ('Noel Fernandez Agroindustrial Complex', 'FAC'), ('11', 'CARDINAL'), ('Ulises Rosales del Toro', 'PERSON'), ('First Party', 'ORG'), ('Carlos Diaz Barranco', 'PERSON'), ('Rosales del Toro', 'PERSON'), ('Rosales del Toro', 'PERSON'), ('Politburo', 'ORG'), ('The Sunday Times', 'ORG'), ('NATO', 'ORG'), ('18,000', 'CARDINAL'), ('Balkans', 'LOC'), ('Yugoslavia', 'GPE'), ('Anthony Blair', 'PERSON'), ('William Clinton', 'PERSON'), ('NATO', 'ORG'), ('Yugoslavia', 'GPE'), ('Belgrade', 'GPE'), ('night', 'TIME'), ('Serbia', 'GPE'), ('6.[07', 'CARDINAL'), ('Social Democrat', 'NORP'), ('Johannes Rau', 'PERSON'), ('German', 'NORP'), ('German Federal Assembly', 'ORG'), ('Colombian', 'NORP'), ('Andres Pastrana', 'PERSON'), ('today', 'DATE'), ("Piedad Cordoba's", 'PERSON'), ('Piedad Cordoba', 'PERSON'), ('Colombian', 'NORP'), ('Congress', 'ORG'), ('Seven', 'CARDINAL'), ('100,000', 'CARDINAL'), ('Germany', 'GPE' ...
# [('Czech', 'NORP'), ('Peruvian', 'NORP'), ('English', 'LANGUAGE'), ('Czech', 'NORP'), ('CTK', 'ORG'), ('Prague', 'GPE'), ('11th January', 'DATE'), ('Jan Kavan', 'PERSON'), ('today', 'DATE'), ('Czech', 'NORP'), ('Peruvian', 'NORP'), ('Peruvian', 'NORP'), ('Fernando de Trazegnies', 'PERSON'), ('today', 'DATE'), ('Kavan', 'ORG'), ('de Trazegnies', 'PERSON'), ('Czech', 'NORP'), ('Czech', 'NORP'), ('Tatra', 'ORG'), ('Peruvian', 'NORP'), ('two', 'CARDINAL'), ('the Czech Republic', 'GPE'), ('Peru', 'GPE'), ('De Trazegnies', 'PERSON'), ('four-day', 'DATE'), ('Prague', 'GPE'), ('Monday [10th January]', 'DATE'), ('the Czech Republic', 'GPE'), ('five', 'CARDINAL'), ('Peruvians', 'NORP'), ('this year', 'DATE'), ('De Trazegnies', 'PERSON'), ('Czech', 'NORP'), ('Peru', 'GPE'), ('Amazon', 'ORG'), ('De Trazegnies', 'PERSON'), ('Czech', 'NORP'), ('Latin America', 'LOC'), ('Peru', 'GPE'), ('Czechoslovak', 'NORP'), ('Peru', 'GPE'), ('CTK', 'ORG'), ('Prague', 'GPE'), ('English', 'LANGUAGE'), ('1314', 'CARDINAL'), ('© British Broadcasting Corporation', 'ORG'), ('http://www.bbcmonitoringonline.com/mmu?page=77&action=view&item=0&srchid=0025ms5&sw=1', 'ORG'), ('25 Jan 00\u2028\u2028', 'DATE'), ("Quito newspaper'El Comercio'and", 'ORG'), ('Guayaquil', 'GPE'), ('Spanish', 'LANGUAGE'), ('25th January', 'DATE'), ('Indians', 'NORP'), ('Civil War', 'EVENT'), ('Indian', 'NORP'), ('Antonio Vargas', 'PERSON'), ('eight hours', 'TIME'), ('yesterday', 'DATE'), ('Mahuad', 'PERSON'), ('Vargas', 'PERSON'), ('Conaie [Confederation of Indigenous Nationalities', 'ORG'), ('Ecuador', 'GPE'), ('the Military High Command', 'ORG'), ('Carlos Mendoza', 'PERSON'), ('Mendoza', 'PERSON'), ('just a few hours later', 'TIME'), ('2200', 'CARDINAL'), ('21st January', 'DATE'), ('the Government Palace', 'FAC'), ('three', 'CARDINAL'), ('Gen Mendoza', 'PERSON'), ('Salvador Quishpe', 'PERSON'), ('Ecuarunari', 'ORG'), ('Conaie', 'PERSON'), ('Vargas', 'PERSON'), ('Mendoza', 'PERSON'), ('the Joint Command', 'ORG'), ('Telmo Sandoval', 'PERSON'), ('El Universo', 'ORG'), ('25th January', 'DATE'), ('Gen Carlos Mendoza', 'PERSON'), ('2300', 'CARDINAL'), ('21st January', 'DATE'), ('Antonio Vargas', 'PERSON'), ('Ecuavisa', 'PERSON'), ('1', 'CARDINAL'), ('2', 'CARDINAL'), ('3', 'CARDINAL'), ('4', 'CARDINAL'), ('5', 'CARDINAL'), ('the National Police', 'ORG'), ('El Universo', 'ORG'), ('25th January', 'DATE'), ('Noboa Confirms Sandoval', 'PERSON'), ('Military High Command', 'ORG'), ('yesterday', 'DATE'), ('Noboa', 'PERSON'), ('Eduardo Monteverde', 'PERSON'), ('Ricardo Irigoyen', 'PERSON'), ('Noboa', 'PERSON'), ('Telmo Sandoval', 'PERSON'), ('the Joint Command', 'ORG'), ('Noboa', 'PERSON'), ('Norton Navarez', 'PERSON'), ('Carondelet', 'ORG'), ('yesterday', 'DATE'), ('morning', 'TIME'), ('the Military High Command', 'ORG'), ('Gen Jose Gallardo', 'PERSON'), ('Noboa', 'PERSON'), ('four', 'CARDINAL'), ('yesterday', 'DATE'), ('Francisco Carrion Mena', 'PERSON'), ('El Universo', 'GPE'), ('25th January', 'DATE'), ('the Military High Command', 'ORG'), ('Col Marco Granja', 'PERSON'), ('the Defence Ministry', 'ORG'), ('21st January', 'DATE'), ('approximately 300', 'CARDINAL'), ('El Universo', 'ORG'), ('25th January', 'DATE'), ('Coup', 'ORG'), ('Congress', 'ORG'), ('Indians', 'NORP'), ('Col Lucio Gutierrez', 'PERSON'), ('Gen Mendoza', 'PERSON'), ('Mahuad', 'PERSON'), ('Defence', 'ORG'), ('Gene Mendoza', 'PERSON'), ('21st January', 'DATE'), ('Mahuad', 'ORG'), ('Benjamin Ortiz', 'PERSON'), ('Ortiz', 'PERSON'), ('Mendoza', 'PERSON'), ('Fujimori', 'GPE'), ('Ortiz', 'PERSON'), ('Mahuad', 'PERSON'), ('Vladimiro Alvarez', 'PERSON'), ('Mendoza', 'PERSON'), ('Mahuad', 'PERSON'), ('Congress', 'ORG'), ('Ortiz', 'PERSON'), ('Mendoza', 'PERSON'), ('Yesterday', 'DATE'), ('Pachakutik', 'ORG'), ('Antonio Posso', 'PERSON'), ('Defence', 'ORG'), ('Jose Gallardo', 'PERSON'), ('Indian', 'NORP'), ('Antonio Vargas', 'PERSON'), ('El Universo', 'GPE'), ('25th January', 'DATE'), ('Pacheco', 'PERSON'), ('Guillermo Pacheco Perez', 'PERSON' ...
# CPU times: user 2.17 s, sys: 428 ms, total: 2.6 s
# Wall time: 2.61 s

# %%
# Out:
# 'Nigeria: Pan-Niger Delta summit calls for full control of resources\u2028\u2028Excerpt from article by Akpa Esajere entitled: "Federalism Tops Talks As Pan-Niger Delta Summit Begins" published by Nigerian newspaper The Guardian web site on 20 October\nCalls for a competitive federalism where federating units will have 100 per cent control of resources in their domain and pay tax to the central government formed the thrust of opinions yesterday as the first Pan-Niger Delta conference of Ethnic Nationalities got under way in Calabar.\nExpectedly, speakers at the conference taking place in the Chinua Achebe Arts theatre, University of Calabar, also harped on familiar themes, notably restructuring and resource control.\nThe participants canvassed 100 per cent control of resources.\nImportantly, they want the country restructured into six zones and made functional like the regions of the First Republic.\nPresident of Ethnic Nationality Forum for the Niger Delta Area Chief David Dafinone in a keyonote address set the tone of the conference as follows: "It is pertinent to state that 100 per cent resources control by the ethnic nationalities with appropriate tax paid to the federal government is a derivable practice.\n"On this issue of resource control, let us agree at this conference that there is no alternative. We need a strong board of trustees to safeguard and represent the interest of the communities from where the oil and gas is derived."\nThe conference kicked off amid tight security with guests thoroughly frisked by local security agents.\nGovernor of Cross River State Mr Donald Duke; former Information Minister Tony Momoh; Chairman of Bayelsa Traditional Rulers; Council Chief Raph Iwowari Mein VII; a frontline minority activist, Mr Margaret Ekpo; former chairman of OMPADEC Chief Albert Horsfall; member, Federal House of Representative Chief Nduese Essien; former ECOMOG Commander Maj-Gen Felix Mujakper; First Minister of Petroleum Dr Mfio Akobo; Professor Willie Okowa; Bishop Uses of Ikot Ekpene Diocese were also present at the well attended conference.\nOn socio-economic development, Dafinone said "the Niger Delta has suffered gross neglect and deprivation over the years despite its enormous contributions to the economic prosperity of the country.\n"As a result of this utter neglect, there is widespread poverty, complete lack of basic utilities (and) there is high rate of unemployment and crime (and) this state of affairs has in turn bred a frustrated population, ethnic polarization, communal suspicion, anti-establishment agitation and hostility, all of which create instability and impede development."\nHe argued that the Niger-Delta needs "a master plan for the area but as a first step, we need a four carriage all-season road from Benin to Akwa Ibom as well as a southern railway to cover the area.\nAccording to him, obnoxious and unjust laws in the country\'s statute such as the Land Use Act 1978, the Petroleum Act 1969 (as amended), Land Title Vesting Decree 1993, National Inland Waterways Authority Decree 1997, the Mineral Act and others have been used to deprive the Niger Delta of amenities and these should be abolished.\nDafinone, who paid tributes to the late Chief Obafemi Awolowo, Dr Nnamdi Azikiwe, the Sardauna of Sokoto, Dr Clement Isong, Chief Omo-Osagie and the late Ken Saro-Wiva among others submitted that Nigeria should be restructured... [newspaper ellipsis] and that the time for a national conference is now."\n"What we thought was our black gold is today our black death (and) the stationing of special boats equipped with instruments for mass destruction to police our shore for the purpose of oil exploration and the exploitation is not the answer" he observed...\n\u2028\u2028Source: The Guardian web site, Lagos, in English 20 Oct 01\u2028\u2028BBC Mon AF1 AFEauwaf 211001/cnob \n© British Broadcasting Corporation 2001\n\u2028 HYPERLINK "http://www.bbcmonitoringonline.com/mmu?page=77&action=view&item=0&srchid=00 ...
