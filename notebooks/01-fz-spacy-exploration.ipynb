# %% [markdown]
# # Explore **spacy** package
# Felix Zaussinger | 06.01.2021
#
# ## Core Analysis Goal(s)
# 1. Discover core functionalities of spacy library
# 2. Test pre-processing chains on example documents from BBC Monitoring
# 3. Test simple models
#
# ## Key Insight(s)
# 1.
# 2.
# 3.

# %%
import os
import sys
import logging
from pathlib import Path

import numpy as np
import scipy as sp
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (16, 9.)})
sns.set_style("ticks")

import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

logging.basicConfig(level=logging.INFO, stream=sys.stdout)

# %% [markdown]
# Define directory structure

# %%
# project directory
abspath = os.path.abspath('')
project_dir = str(Path(abspath).parents[0])

# sub-directories
data_raw = os.path.join(project_dir, "data", "raw")
data_interim = os.path.join(project_dir, "data", "interim")
data_processed = os.path.join(project_dir, "data", "processed")
figure_dir = os.path.join(project_dir, "plots")

# %% [markdown]
# Code ...

# %%
import glob
import os

dp_string = os.path.join(data_raw, "BBC_2007_07_04_TXT", "*.txt")
file_list = glob.glob(dp_string)

file_list = sorted(file_list)

# %%
n = 10
corpus = []
for file_path in file_list[:n]:
    with open(file_path) as f_input:
        corpus.append(f_input.read())

# %%
import spacy

# init language object
# nlp = spacy.load("en_core_web_sm")
nlp = spacy.load('en_core_web_lg')

# %%
# processed DOC
doc = nlp(corpus[0])

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
    print(token.has_vector, token.vector_norm, token.is_oov)
# Out:
# Nigeria Nigeria PROPN NNP ROOT Xxxxx True False
# True 6.989754 False
# : : PUNCT : punct : False False
# True 5.474056 False
# Pan Pan PROPN NNP compound Xxx True False
# True 7.387207 False
# - - PROPN NNP punct - False False
# True 5.6033444 False
# Niger Niger PROPN NNP compound Xxxxx True False
# True 7.3060813 False
# Delta Delta PROPN NNP compound Xxxxx True False
# True 6.704845 False
# summit summit NOUN NN nsubj xxxx True False
# True 7.074887 False
# calls call VERB VBZ ROOT xxxx True False
# True 5.695754 False
# for for ADP IN prep xxx True True
# True 4.8435082 False
# full full ADJ JJ amod xxxx True True
# True 5.2046375 False
# control control NOUN NN pobj xxxx True False
# True 6.4051557 False
# of of ADP IN prep xx True True
# True 4.97793 False
# resources resource NOUN NNS nmod xxxx True False
# True 6.2951474 False
#   SPACE _SP   False False
# False 0.0 True
# Excerpt Excerpt PROPN NNP pobj Xxxxx True False
# True 5.3811 False
# from from ADP IN prep xxxx True True
# True 5.093107 False
# article article NOUN NN pobj xxxx True False
# True 5.739202 False
# by by ADP IN prep xx True True
# True 6.015159 False
# Akpa Akpa PROPN NNP compound Xxxx True False
# False 0.0 True
# Esajere Esajere PROPN NNP pobj Xxxxx True False
# False 0.0 True
# entitled entitle VERB VBN advcl xxxx True False
# True 5.8760266 False
# : : PUNCT : punct : False False
# True 5.474056 False
# " " PUNCT `` punct " False False
# True 5.3378205 False
# Federalism Federalism PROPN NNP compound Xxxxx True False
# True 7.069139 False
# Tops Tops PROPN NNP compound Xxxx True False
# True 5.848152 False
# Talks Talks PROPN NNPS dobj Xxxxx True False
# True 5.8017697 False
# As as SCONJ IN mark Xx True True
# True 4.5106106 False
# Pan Pan PROPN NNP dep Xxx True False
# True 7.387207 False
# - - PROPN NNP punct - False False
# True 5.6033444 False
# Niger Niger PROPN NNP compound Xxxxx True False
# True 7.3060813 False
# Delta Delta PROPN NNP compound Xxxxx True False
# True 6.704845 False
# Summit Summit PROPN NNP nsubj Xxxxx True False
# True 7.074887 False
# Begins begin VERB VBZ auxpass Xxxxx True False
# True 5.61649 False
# " " PUNCT '' punct " False False
# True 5.3378205 False
# published publish VERB VBN ROOT xxxx True False
# True 6.62521 False
# by by ADP IN agent xx True True
# True 6.015159 False
# Nigerian nigerian ADJ JJ amod Xxxxx True False
# True 7.1590686 False
# newspaper newspaper NOUN NN pobj xxxx True False
# True 7.116756 False
# The the DET DT det Xxx True True
# True 4.70935 False
# Guardian Guardian PROPN NNP compound Xxxxx True False
# True 6.2794085 False
# web web NOUN NN compound xxx True False
# True 6.444398 False
# site site NOUN NN nsubj xxxx True False
# True 6.315663 False
# on on ADP IN prep xx True True
# True 5.218119 False
# 20 20 NUM CD nummod dd False False
# True 5.2563577 False
# October October PROPN NNP pobj Xxxxx True False
# True 6.03853 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# Calls call NOUN NNS nsubj Xxxxx True False
# True 5.695754 False
# for for ADP IN prep xxx True True
# True 4.8435082 False
# a a DET DT det x True True
# True 5.306696 False
# competitive competitive ADJ JJ amod xxxx True False
# True 6.330761 False
# federalism federalism NOUN NN pobj xxxx True False
# True 7.069139 False
# where where ADV WRB advmod xxxx True True
# True 4.8468976 False
# federating federate VERB VBG amod xxxx True False
# True 7.2100554 False
# units unit NOUN NNS nsubj xxxx True False
# True 6.6013503 False
# will will VERB MD aux xxxx True True
# True 5.1590676 False
# have have AUX VB relcl xxxx True True
# True 5.036123 False
# 100 100 NUM CD nummod ddd False False
# True 5.708493 False
# per per ADP IN nmod xxx True True
# True 7.0907845 False
# cent cent NOUN NN pobj xxxx True False
# True 7.026296 False
# control control NOUN NN dobj xxxx True False
# True 6.4051557 False
# of of ADP IN prep xx True True
# True 4.97793 False
# resources resource NOUN NNS pobj xxxx True False
# True 6.2951474 False
# in in ADP IN prep xx True True
# True 5.0929856 False
# their -PRON- DET PRP$ poss xxxx True True
# True 5.697708 False
# domain domain NOUN NN pobj xxxx True False
# True 7.2541904 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# pay pay VERB VB conj xxx True False
# True 6.239512 False
# tax tax NOUN NN dobj xxx True False
# True 7.360619 False
# to to ADP IN prep xx True True
# True 4.74484 False
# the the DET DT det xxx True True
# True 4.70935 False
# central central ADJ JJ amod xxxx True False
# True 6.2224474 False
# government government NOUN NN pobj xxxx True False
# True 6.9297547 False
# formed form VERB VBD ROOT xxxx True False
# True 6.429462 False
# the the DET DT det xxx True True
# True 4.70935 False
# thrust thrust NOUN NN dobj xxxx True False
# True 6.0804033 False
# of of ADP IN prep xx True True
# True 4.97793 False
# opinions opinion NOUN NNS pobj xxxx True False
# True 6.28736 False
# yesterday yesterday NOUN NN npadvmod xxxx True False
# True 5.691575 False
# as as SCONJ IN mark xx True True
# True 4.5106106 False
# the the DET DT det xxx True True
# True 4.70935 False
# first first ADJ JJ amod xxxx True True
# True 5.042608 False
# Pan Pan PROPN NNP dep Xxx True False
# True 7.387207 False
# - - PROPN NNP punct - False False
# True 5.6033444 False
# Niger Niger PROPN NNP compound Xxxxx True False
# True 7.3060813 False
# Delta Delta PROPN NNP compound Xxxxx True False
# True 6.704845 False
# conference conference NOUN NN nsubj xxxx True False
# True 6.6279144 False
# of of ADP IN prep xx True True
# True 4.97793 False
# Ethnic Ethnic PROPN NNP amod Xxxxx True False
# True 7.685203 False
# Nationalities Nationalities PROPN NNPS pobj Xxxxx True False
# True 6.903108 False
# got get VERB VBD advcl xxx True False
# True 5.3200083 False
# under under ADP IN prep xxxx True True
# True 5.7479024 False
# way way NOUN NN pobj xxx True False
# True 4.760437 False
# in in ADP IN prep xx True True
# True 5.0929856 False
# Calabar Calabar PROPN NNP pobj Xxxxx True False
# False 0.0 True
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# Expectedly Expectedly PROPN NNP advmod Xxxxx True False
# False 0.0 True
# , , PUNCT , punct , False False
# True 5.094723 False
# speakers speaker NOUN NNS nsubj xxxx True False
# True 7.167468 False
# at at ADP IN prep xx True True
# True 6.0998254 False
# the the DET DT det xxx True True
# True 4.70935 False
# conference conference NOUN NN pobj xxxx True False
# True 6.6279144 False
# taking take VERB VBG acl xxxx True False
# True 5.2954054 False
# place place NOUN NN dobj xxxx True False
# True 5.0296216 False
# in in ADP IN prep xx True True
# True 5.0929856 False
# the the DET DT det xxx True True
# True 4.70935 False
# Chinua Chinua PROPN NNP compound Xxxxx True False
# True 8.927026 False
# Achebe Achebe PROPN NNP compound Xxxxx True False
# True 8.564181 False
# Arts arts PART POS compound Xxxx True False
# True 6.9502425 False
# theatre theatre NOUN NN pobj xxxx True False
# True 6.7481437 False
# , , PUNCT , punct , False False
# True 5.094723 False
# University University PROPN NNP appos Xxxxx True False
# True 6.8914504 False
# of of ADP IN prep xx True True
# True 4.97793 False
# Calabar Calabar PROPN NNP pobj Xxxxx True False
# False 0.0 True
# , , PUNCT , punct , False False
# True 5.094723 False
# also also ADV RB advmod xxxx True True
# True 4.801285 False
# harped harp VERB VBD ROOT xxxx True False
# True 6.4744477 False
# on on ADP IN prep xx True True
# True 5.218119 False
# familiar familiar ADJ JJ amod xxxx True False
# True 5.019752 False
# themes theme NOUN NNS pobj xxxx True False
# True 6.853786 False
# , , PUNCT , punct , False False
# True 5.094723 False
# notably notably ADV RB advmod xxxx True False
# True 4.829612 False
# restructuring restructuring NOUN NN appos xxxx True False
# True 6.911564 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# resource resource NOUN NN compound xxxx True False
# True 6.251959 False
# control control NOUN NN conj xxxx True False
# True 6.4051557 False
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# The the DET DT det Xxx True True
# True 4.70935 False
# participants participant NOUN NNS nsubj xxxx True False
# True 6.278505 False
# canvassed canvass VERB VBD ROOT xxxx True False
# True 5.970639 False
# 100 100 NUM CD nummod ddd False False
# True 5.708493 False
# per per ADP IN prep xxx True True
# True 7.0907845 False
# cent cent NOUN NN pobj xxxx True False
# True 7.026296 False
# control control NOUN NN dobj xxxx True False
# True 6.4051557 False
# of of ADP IN prep xx True True
# True 4.97793 False
# resources resource NOUN NNS pobj xxxx True False
# True 6.2951474 False
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# Importantly importantly ADV RB advmod Xxxxx True False
# True 4.758769 False
# , , PUNCT , punct , False False
# True 5.094723 False
# they -PRON- PRON PRP nsubj xxxx True True
# True 5.409625 False
# want want VERB VBP ROOT xxxx True False
# True 5.2187786 False
# the the DET DT det xxx True True
# True 4.70935 False
# country country NOUN NN nsubj xxxx True False
# True 6.06488 False
# restructured restructure VERB VBN ccomp xxxx True False
# True 6.077029 False
# into into ADP IN prep xxxx True True
# True 5.2429595 False
# six six NUM CD nummod xxx True True
# True 5.694776 False
# zones zone NOUN NNS pobj xxxx True False
# True 6.514576 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# made make VERB VBD conj xxxx True True
# True 4.963541 False
# functional functional ADJ JJ oprd xxxx True False
# True 6.253166 False
# like like SCONJ IN prep xxxx True False
# True 4.78322 False
# the the DET DT det xxx True True
# True 4.70935 False
# regions region NOUN NNS pobj xxxx True False
# True 7.184921 False
# of of ADP IN prep xx True True
# True 4.97793 False
# the the DET DT det xxx True True
# True 4.70935 False
# First First PROPN NNP compound Xxxxx True True
# True 5.042608 False
# Republic Republic PROPN NNP pobj Xxxxx True False
# True 6.601141 False
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# President President PROPN NNP nsubj Xxxxx True False
# True 7.123663 False
# of of ADP IN prep xx True True
# True 4.97793 False
# Ethnic Ethnic PROPN NNP amod Xxxxx True False
# True 7.685203 False
# Nationality Nationality PROPN NNP compound Xxxxx True False
# True 6.704322 False
# Forum Forum PROPN NNP pobj Xxxxx True False
# True 6.4767966 False
# for for ADP IN prep xxx True True
# True 4.8435082 False
# the the DET DT det xxx True True
# True 4.70935 False
# Niger Niger PROPN NNP compound Xxxxx True False
# True 7.3060813 False
# Delta Delta PROPN NNP compound Xxxxx True False
# True 6.704845 False
# Area Area PROPN NNP compound Xxxx True False
# True 6.0860114 False
# Chief Chief PROPN NNP compound Xxxxx True False
# True 6.982485 False
# David David PROPN NNP compound Xxxxx True False
# True 6.5919833 False
# Dafinone Dafinone PROPN NNP pobj Xxxxx True False
# False 0.0 True
# in in ADP IN prep xx True True
# True 5.0929856 False
# a a DET DT det x True True
# True 5.306696 False
# keyonote keyonote PROPN NNP compound xxxx True False
# False 0.0 True
# address address NOUN NN pobj xxxx True False
# True 6.138033 False
# set set VERB VBD ROOT xxx True False
# True 5.176063 False
# the the DET DT det xxx True True
# True 4.70935 False
# tone tone NOUN NN dobj xxxx True False
# True 6.8149476 False
# of of ADP IN prep xx True True
# True 4.97793 False
# the the DET DT det xxx True True
# True 4.70935 False
# conference conference NOUN NN pobj xxxx True False
# True 6.6279144 False
# as as SCONJ IN mark xx True True
# True 4.5106106 False
# follows follow VERB VBZ advcl xxxx True False
# True 4.6924553 False
# : : PUNCT : punct : False False
# True 5.474056 False
# " " PUNCT `` punct " False False
# True 5.3378205 False
# It -PRON- PRON PRP nsubj Xx True True
# True 4.9409766 False
# is be AUX VBZ ccomp xx True True
# True 4.890306 False
# pertinent pertinent ADJ JJ acomp xxxx True False
# True 5.6587996 False
# to to ADP IN prep xx True True
# True 4.74484 False
# state state NOUN NN pobj xxxx True False
# True 6.483711 False
# that that SCONJ IN mark xxxx True True
# True 4.8260193 False
# 100 100 NUM CD nummod ddd False False
# True 5.708493 False
# per per ADP IN quantmod xxx True True
# True 7.0907845 False
# cent cent NOUN NN compound xxxx True False
# True 7.026296 False
# resources resource NOUN NNS compound xxxx True False
# True 6.2951474 False
# control control NOUN NN nsubj xxxx True False
# True 6.4051557 False
# by by ADP IN prep xx True True
# True 6.015159 False
# the the DET DT det xxx True True
# True 4.70935 False
# ethnic ethnic ADJ JJ amod xxxx True False
# True 7.685203 False
# nationalities nationality NOUN NNS pobj xxxx True False
# True 6.903108 False
# with with ADP IN prep xxxx True True
# True 4.7708583 False
# appropriate appropriate ADJ JJ amod xxxx True False
# True 5.6778684 False
# tax tax NOUN NN pobj xxx True False
# True 7.360619 False
# paid pay VERB VBN acl xxxx True False
# True 6.026424 False
# to to ADP IN prep xx True True
# True 4.74484 False
# the the DET DT det xxx True True
# True 4.70935 False
# federal federal ADJ JJ amod xxxx True False
# True 7.290302 False
# government government NOUN NN pobj xxxx True False
# True 6.9297547 False
# is be AUX VBZ ccomp xx True True
# True 4.890306 False
# a a DET DT det x True True
# True 5.306696 False
# derivable derivable ADJ JJ amod xxxx True False
# True 6.453997 False
# practice practice NOUN NN attr xxxx True False
# True 6.5172915 False
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# " " PUNCT `` punct " False False
# True 5.3378205 False
# On on ADP IN prep Xx True True
# True 5.218119 False
# this this DET DT det xxxx True True
# True 5.0461264 False
# issue issue NOUN NN pobj xxxx True False
# True 5.775942 False
# of of ADP IN prep xx True True
# True 4.97793 False
# resource resource NOUN NN compound xxxx True False
# True 6.251959 False
# control control NOUN NN pobj xxxx True False
# True 6.4051557 False
# , , PUNCT , punct , False False
# True 5.094723 False
# let let VERB VB ROOT xxx True False
# True 5.297676 False
# us -PRON- PRON PRP nsubj xx True True
# True 5.6036463 False
# agree agree VERB VB ccomp xxxx True False
# True 5.6068487 False
# at at ADP IN prep xx True True
# True 6.0998254 False
# this this DET DT det xxxx True True
# True 5.0461264 False
# conference conference NOUN NN pobj xxxx True False
# True 6.6279144 False
# that that SCONJ IN mark xxxx True True
# True 4.8260193 False
# there there PRON EX expl xxxx True True
# True 4.8072896 False
# is be AUX VBZ ccomp xx True True
# True 4.890306 False
# no no DET DT det xx True True
# True 5.3881946 False
# alternative alternative NOUN NN attr xxxx True False
# True 5.6756954 False
# . . PUNCT . punct . False False
# True 4.9316354 False
# We -PRON- PRON PRP nsubj Xx True True
# True 5.260865 False
# need need VERB VBP ROOT xxxx True False
# True 5.173026 False
# a a DET DT det x True True
# True 5.306696 False
# strong strong ADJ JJ amod xxxx True False
# True 5.7850513 False
# board board NOUN NN dobj xxxx True False
# True 6.1905437 False
# of of ADP IN prep xx True True
# True 4.97793 False
# trustees trustee NOUN NNS pobj xxxx True False
# True 6.86508 False
# to to PART TO aux xx True True
# True 4.74484 False
# safeguard safeguard VERB VB advcl xxxx True False
# True 5.9467587 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# represent represent VERB VB conj xxxx True False
# True 5.2212467 False
# the the DET DT det xxx True True
# True 4.70935 False
# interest interest NOUN NN dobj xxxx True False
# True 5.751332 False
# of of ADP IN prep xx True True
# True 4.97793 False
# the the DET DT det xxx True True
# True 4.70935 False
# communities community NOUN NNS pobj xxxx True False
# True 6.963073 False
# from from ADP IN prep xxxx True True
# True 5.093107 False
# where where ADV WRB advmod xxxx True True
# True 4.8468976 False
# the the DET DT det xxx True True
# True 4.70935 False
# oil oil NOUN NN nsubjpass xxx True False
# True 7.9124475 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# gas gas NOUN NN conj xxx True False
# True 7.3801517 False
# is be AUX VBZ auxpass xx True True
# True 4.890306 False
# derived derive VERB VBN pcomp xxxx True False
# True 6.0363736 False
# . . PUNCT . punct . False False
# True 4.9316354 False
# " " PUNCT '' punct " False False
# True 5.3378205 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# The the DET DT det Xxx True True
# True 4.70935 False
# conference conference NOUN NN nsubj xxxx True False
# True 6.6279144 False
# kicked kick VERB VBD ROOT xxxx True False
# True 5.4960065 False
# off off ADP RP prt xxx True True
# True 5.156806 False
# amid amid ADP IN prep xxxx True False
# True 6.3873057 False
# tight tight ADJ JJ amod xxxx True False
# True 6.7135096 False
# security security NOUN NN pobj xxxx True False
# True 7.0936003 False
# with with ADP IN prep xxxx True True
# True 4.7708583 False
# guests guest NOUN NNS pobj xxxx True False
# True 6.8545566 False
# thoroughly thoroughly ADV RB advmod xxxx True False
# True 6.0846133 False
# frisked frisk VERB VBN acl xxxx True False
# True 7.343001 False
# by by ADP IN agent xx True True
# True 6.015159 False
# local local ADJ JJ amod xxxx True False
# True 6.11321 False
# security security NOUN NN compound xxxx True False
# True 7.0936003 False
# agents agent NOUN NNS pobj xxxx True False
# True 7.210123 False
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# Governor Governor PROPN NNP nmod Xxxxx True False
# True 7.3845534 False
# of of ADP IN prep xx True True
# True 4.97793 False
# Cross Cross PROPN NNP compound Xxxxx True False
# True 5.992751 False
# River River PROPN NNP compound Xxxxx True False
# True 7.4749465 False
# State State PROPN NNP pobj Xxxxx True False
# True 6.483711 False
# Mr Mr PROPN NNP compound Xx True False
# True 6.135809 False
# Donald Donald PROPN NNP compound Xxxxx True False
# True 6.4072695 False
# Duke Duke PROPN NNP ROOT Xxxx True False
# True 6.347861 False
# ; ; PUNCT : punct ; False False
# True 5.665907 False
# former former ADJ JJ amod xxxx True True
# True 6.340791 False
# Information Information PROPN NNP compound Xxxxx True False
# True 5.9842715 False
# Minister Minister PROPN NNP compound Xxxxx True False
# True 7.629945 False
# Tony Tony PROPN NNP compound Xxxx True False
# True 6.2008142 False
# Momoh Momoh PROPN NNP conj Xxxxx True False
# False 0.0 True
# ; ; PUNCT : punct ; False False
# True 5.665907 False
# Chairman Chairman PROPN NNP appos Xxxxx True False
# True 7.1772027 False
# of of ADP IN prep xx True True
# True 4.97793 False
# Bayelsa Bayelsa PROPN NNP compound Xxxxx True False
# False 0.0 True
# Traditional Traditional PROPN NNP compound Xxxxx True False
# True 6.562152 False
# Rulers Rulers PROPN NNPS pobj Xxxxx True False
# True 7.2161326 False
# ; ; PUNCT : punct ; False False
# True 5.665907 False
# Council Council PROPN NNP compound Xxxxx True False
# True 6.6299386 False
# Chief Chief PROPN NNP compound Xxxxx True False
# True 6.982485 False
# Raph Raph PROPN NNP compound Xxxx True False
# True 7.1313477 False
# Iwowari Iwowari PROPN NNP compound Xxxxx True False
# False 0.0 True
# Mein Mein PROPN NNP compound Xxxx True False
# True 8.067234 False
# VII VII PROPN NNP appos XXX True False
# True 6.0256605 False
# ; ; PUNCT : punct ; False False
# True 5.665907 False
# a a DET DT det x True True
# True 5.306696 False
# frontline frontline ADJ JJ amod xxxx True False
# True 6.1580815 False
# minority minority NOUN NN compound xxxx True False
# True 6.748301 False
# activist activist NOUN NN appos xxxx True False
# True 7.2026534 False
# , , PUNCT , punct , False False
# True 5.094723 False
# Mr Mr PROPN NNP compound Xx True False
# True 6.135809 False
# Margaret Margaret PROPN NNP compound Xxxxx True False
# True 6.040842 False
# Ekpo Ekpo PROPN NNP appos Xxxx True False
# False 0.0 True
# ; ; PUNCT , punct ; False False
# True 5.665907 False
# former former ADJ JJ amod xxxx True True
# True 6.340791 False
# chairman chairman NOUN NN appos xxxx True False
# True 7.1772027 False
# of of ADP IN prep xx True True
# True 4.97793 False
# OMPADEC OMPADEC PROPN NNP compound XXXX True False
# False 0.0 True
# Chief Chief PROPN NNP compound Xxxxx True False
# True 6.982485 False
# Albert Albert PROPN NNP compound Xxxxx True False
# True 6.2472787 False
# Horsfall Horsfall PROPN NNP pobj Xxxxx True False
# False 0.0 True
# ; ; PUNCT : punct ; False False
# True 5.665907 False
# member member NOUN NN appos xxxx True False
# True 6.6626935 False
# , , PUNCT , punct , False False
# True 5.094723 False
# Federal Federal PROPN NNP compound Xxxxx True False
# True 7.290302 False
# House House PROPN NNP conj Xxxxx True False
# True 6.0780153 False
# of of ADP IN prep xx True True
# True 4.97793 False
# Representative Representative PROPN NNP compound Xxxxx True False
# True 5.457906 False
# Chief Chief PROPN NNP compound Xxxxx True False
# True 6.982485 False
# Nduese Nduese PROPN NNP compound Xxxxx True False
# False 0.0 True
# Essien Essien PROPN NNP pobj Xxxxx True False
# True 9.919603 False
# ; ; PUNCT : punct ; False False
# True 5.665907 False
# former former ADJ JJ amod xxxx True True
# True 6.340791 False
# ECOMOG ECOMOG PROPN NNP compound XXXX True False
# False 0.0 True
# Commander Commander PROPN NNP compound Xxxxx True False
# True 7.1496534 False
# Maj Maj PROPN NNP dep Xxx True False
# True 7.7633424 False
# - - PUNCT HYPH punct - False False
# True 5.6033444 False
# Gen Gen PROPN NNP compound Xxx True False
# True 6.34747 False
# Felix Felix PROPN NNP compound Xxxxx True False
# True 5.9663525 False
# Mujakper Mujakper PROPN NNP appos Xxxxx True False
# False 0.0 True
# ; ; PUNCT : punct ; False False
# True 5.665907 False
# First First PROPN NNP compound Xxxxx True True
# True 5.042608 False
# Minister Minister PROPN NNP nmod Xxxxx True False
# True 7.629945 False
# of of ADP IN prep xx True True
# True 4.97793 False
# Petroleum Petroleum PROPN NNP pobj Xxxxx True False
# True 7.398595 False
# Dr Dr PROPN NNP compound Xx True False
# True 6.625482 False
# Mfio Mfio PROPN NNP compound Xxxx True False
# False 0.0 True
# Akobo Akobo PROPN NNP conj Xxxxx True False
# False 0.0 True
# ; ; PUNCT : punct ; False False
# True 5.665907 False
# Professor Professor PROPN NNP compound Xxxxx True False
# True 7.361087 False
# Willie Willie PROPN NNP compound Xxxxx True False
# True 6.5570927 False
# Okowa Okowa PROPN NNP conj Xxxxx True False
# False 0.0 True
# ; ; PUNCT : punct ; False False
# True 5.665907 False
# Bishop Bishop PROPN NNP compound Xxxxx True False
# True 7.4895225 False
# Uses use VERB VBZ nsubj Xxxx True False
# True 5.4404235 False
# of of ADP IN prep xx True True
# True 4.97793 False
# Ikot Ikot PROPN NNP compound Xxxx True False
# False 0.0 True
# Ekpene Ekpene PROPN NNP compound Xxxxx True False
# False 0.0 True
# Diocese Diocese PROPN NNP pobj Xxxxx True False
# True 7.4311004 False
# were be AUX VBD parataxis xxxx True True
# True 6.003382 False
# also also ADV RB advmod xxxx True True
# True 4.801285 False
# present present ADJ JJ acomp xxxx True False
# True 4.92786 False
# at at ADP IN prep xx True True
# True 6.0998254 False
# the the DET DT det xxx True True
# True 4.70935 False
# well well ADV RB advmod xxxx True True
# True 4.615075 False
# attended attended ADJ JJ amod xxxx True False
# True 6.2321525 False
# conference conference NOUN NN pobj xxxx True False
# True 6.6279144 False
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# On on ADP IN prep Xx True True
# True 5.218119 False
# socio socio ADJ JJ dep xxxx True False
# True 6.6687307 False
# - - ADJ JJ dep - False False
# True 5.6033444 False
# economic economic ADJ JJ amod xxxx True False
# True 7.0918612 False
# development development NOUN NN pobj xxxx True False
# True 6.4843516 False
# , , PUNCT , punct , False False
# True 5.094723 False
# Dafinone Dafinone PROPN NNP nsubj Xxxxx True False
# False 0.0 True
# said say VERB VBD ROOT xxxx True False
# True 6.524705 False
# " " PUNCT `` punct " False False
# True 5.3378205 False
# the the DET DT det xxx True True
# True 4.70935 False
# Niger Niger PROPN NNP compound Xxxxx True False
# True 7.3060813 False
# Delta Delta PROPN NNP nsubj Xxxxx True False
# True 6.704845 False
# has have AUX VBZ aux xxx True True
# True 5.028274 False
# suffered suffer VERB VBN ccomp xxxx True False
# True 6.589432 False
# gross gross ADJ JJ amod xxxx True False
# True 6.7099147 False
# neglect neglect NOUN NN dobj xxxx True False
# True 6.1471233 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# deprivation deprivation NOUN NN conj xxxx True False
# True 6.842396 False
# over over ADP IN prep xxxx True True
# True 5.11742 False
# the the DET DT det xxx True True
# True 4.70935 False
# years year NOUN NNS pobj xxxx True False
# True 5.888022 False
# despite despite SCONJ IN prep xxxx True False
# True 5.235113 False
# its -PRON- DET PRP$ poss xxx True True
# True 5.6994023 False
# enormous enormous ADJ JJ amod xxxx True False
# True 5.842398 False
# contributions contribution NOUN NNS pobj xxxx True False
# True 6.325533 False
# to to ADP IN prep xx True True
# True 4.74484 False
# the the DET DT det xxx True True
# True 4.70935 False
# economic economic ADJ JJ amod xxxx True False
# True 7.0918612 False
# prosperity prosperity NOUN NN pobj xxxx True False
# True 6.7812552 False
# of of ADP IN prep xx True True
# True 4.97793 False
# the the DET DT det xxx True True
# True 4.70935 False
# country country NOUN NN pobj xxxx True False
# True 6.06488 False
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# " " PUNCT `` punct " False False
# True 5.3378205 False
# As as SCONJ IN prep Xx True True
# True 4.5106106 False
# a a DET DT det x True True
# True 5.306696 False
# result result NOUN NN pobj xxxx True False
# True 5.3586297 False
# of of ADP IN prep xx True True
# True 4.97793 False
# this this DET DT det xxxx True True
# True 5.0461264 False
# utter utter ADJ JJ amod xxxx True False
# True 6.1781087 False
# neglect neglect NOUN NN pobj xxxx True False
# True 6.1471233 False
# , , PUNCT , punct , False False
# True 5.094723 False
# there there PRON EX expl xxxx True True
# True 4.8072896 False
# is be AUX VBZ ROOT xx True True
# True 4.890306 False
# widespread widespread ADJ JJ amod xxxx True False
# True 6.167885 False
# poverty poverty NOUN NN attr xxxx True False
# True 7.3632965 False
# , , PUNCT , punct , False False
# True 5.094723 False
# complete complete ADJ JJ amod xxxx True False
# True 5.4999905 False
# lack lack NOUN NN attr xxxx True False
# True 5.7557197 False
# of of ADP IN prep xx True True
# True 4.97793 False
# basic basic ADJ JJ amod xxxx True False
# True 5.828451 False
# utilities utility NOUN NNS pobj xxxx True False
# True 6.9428635 False
# ( ( PUNCT -LRB- punct ( False False
# True 5.781955 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# ) ) PUNCT -RRB- punct ) False False
# True 5.489806 False
# there there PRON EX expl xxxx True True
# True 4.8072896 False
# is be AUX VBZ ROOT xx True True
# True 4.890306 False
# high high ADJ JJ amod xxxx True False
# True 5.846882 False
# rate rate NOUN NN attr xxxx True False
# True 6.8548427 False
# of of ADP IN prep xx True True
# True 4.97793 False
# unemployment unemployment NOUN NN pobj xxxx True False
# True 7.646677 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# crime crime NOUN NN conj xxxx True False
# True 6.8444185 False
# ( ( PUNCT -LRB- punct ( False False
# True 5.781955 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# ) ) PUNCT -RRB- punct ) False False
# True 5.489806 False
# this this DET DT det xxxx True True
# True 5.0461264 False
# state state NOUN NN nsubj xxxx True False
# True 6.483711 False
# of of ADP IN prep xx True True
# True 4.97793 False
# affairs affair NOUN NNS pobj xxxx True False
# True 6.1510158 False
# has have AUX VBZ aux xxx True True
# True 5.028274 False
# in in ADP IN prep xx True True
# True 5.0929856 False
# turn turn NOUN NN pobj xxxx True False
# True 5.074203 False
# bred breed VERB VBD conj xxxx True False
# True 6.8693633 False
# a a DET DT det x True True
# True 5.306696 False
# frustrated frustrated ADJ JJ amod xxxx True False
# True 5.9084077 False
# population population NOUN NN dobj xxxx True False
# True 7.305406 False
# , , PUNCT , punct , False False
# True 5.094723 False
# ethnic ethnic ADJ JJ amod xxxx True False
# True 7.685203 False
# polarization polarization NOUN NN conj xxxx True False
# True 7.578204 False
# , , PUNCT , punct , False False
# True 5.094723 False
# communal communal ADJ JJ amod xxxx True False
# True 6.9540076 False
# suspicion suspicion NOUN NN conj xxxx True False
# True 6.209996 False
# , , PUNCT , punct , False False
# True 5.094723 False
# anti anti ADJ JJ dep xxxx True False
# True 6.9158764 False
# - - ADJ JJ dep - False False
# True 5.6033444 False
# establishment establishment ADJ JJ amod xxxx True False
# True 5.717461 False
# agitation agitation NOUN NN conj xxxx True False
# True 7.012489 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# hostility hostility NOUN NN conj xxxx True False
# True 6.6105685 False
# , , PUNCT , punct , False False
# True 5.094723 False
# all all DET DT nsubj xxx True True
# True 4.932093 False
# of of ADP IN prep xx True True
# True 4.97793 False
# which which DET WDT pobj xxxx True True
# True 4.9601226 False
# create create VERB VBP relcl xxxx True False
# True 5.926105 False
# instability instability NOUN NN dobj xxxx True False
# True 7.0349994 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# impede impede VERB VB conj xxxx True False
# True 6.0759363 False
# development development NOUN NN dobj xxxx True False
# True 6.4843516 False
# . . PUNCT . punct . False False
# True 4.9316354 False
# " " PUNCT '' punct " False False
# True 5.3378205 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# He -PRON- PRON PRP nsubj Xx True True
# True 6.080851 False
# argued argue VERB VBD ROOT xxxx True False
# True 5.759491 False
# that that SCONJ IN mark xxxx True True
# True 4.8260193 False
# the the DET DT det xxx True True
# True 4.70935 False
# Niger Niger PROPN NNP compound Xxxxx True False
# True 7.3060813 False
# - - PUNCT HYPH punct - False False
# True 5.6033444 False
# Delta Delta PROPN NNP nsubj Xxxxx True False
# True 6.704845 False
# needs need VERB VBZ ccomp xxxx True False
# True 5.2958817 False
# " " PUNCT `` punct " False False
# True 5.3378205 False
# a a DET DT det x True True
# True 5.306696 False
# master master NOUN NN compound xxxx True False
# True 6.2861724 False
# plan plan NOUN NN dobj xxxx True False
# True 6.151889 False
# for for ADP IN prep xxx True True
# True 4.8435082 False
# the the DET DT det xxx True True
# True 4.70935 False
# area area NOUN NN pobj xxxx True False
# True 6.0860114 False
# but but CCONJ CC cc xxx True True
# True 4.903002 False
# as as SCONJ IN prep xx True True
# True 4.5106106 False
# a a DET DT det x True True
# True 5.306696 False
# first first ADJ JJ amod xxxx True True
# True 5.042608 False
# step step NOUN NN pobj xxxx True False
# True 5.6605105 False
# , , PUNCT , punct , False False
# True 5.094723 False
# we -PRON- PRON PRP nsubj xx True True
# True 5.260865 False
# need need VERB VBP conj xxxx True False
# True 5.173026 False
# a a DET DT det x True True
# True 5.306696 False
# four four NUM CD nummod xxxx True True
# True 5.6317215 False
# carriage carriage NOUN NN nmod xxxx True False
# True 6.4872727 False
# all all DET DT det xxx True True
# True 4.932093 False
# - - PUNCT HYPH punct - False False
# True 5.6033444 False
# season season NOUN NN compound xxxx True False
# True 7.2339334 False
# road road NOUN NN dobj xxxx True False
# True 6.287687 False
# from from ADP IN prep xxxx True True
# True 5.093107 False
# Benin Benin PROPN NNP pobj Xxxxx True False
# True 7.4952855 False
# to to ADP IN prep xx True True
# True 4.74484 False
# Akwa Akwa PROPN NNP compound Xxxx True False
# False 0.0 True
# Ibom Ibom PROPN NNP pobj Xxxx True False
# False 0.0 True
# as as ADV RB advmod xx True True
# True 4.5106106 False
# well well ADV RB advmod xxxx True True
# True 4.615075 False
# as as SCONJ IN cc xx True True
# True 4.5106106 False
# a a DET DT det x True True
# True 5.306696 False
# southern southern ADJ JJ amod xxxx True False
# True 6.7571673 False
# railway railway NOUN NN conj xxxx True False
# True 7.288404 False
# to to PART TO aux xx True True
# True 4.74484 False
# cover cover VERB VB relcl xxxx True False
# True 6.065769 False
# the the DET DT det xxx True True
# True 4.70935 False
# area area NOUN NN dobj xxxx True False
# True 6.0860114 False
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# According accord VERB VBG prep Xxxxx True False
# True 5.5794687 False
# to to ADP IN prep xx True True
# True 4.74484 False
# him -PRON- PRON PRP pobj xxx True True
# True 6.4110327 False
# , , PUNCT , punct , False False
# True 5.094723 False
# obnoxious obnoxious ADJ JJ amod xxxx True False
# True 6.3071623 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# unjust unjust ADJ JJ conj xxxx True False
# True 7.1811576 False
# laws law NOUN NNS pobj xxxx True False
# True 7.2050476 False
# in in ADP IN prep xx True True
# True 5.0929856 False
# the the DET DT det xxx True True
# True 4.70935 False
# country country NOUN NN poss xxxx True False
# True 6.06488 False
# 's 's PART POS case 'x False True
# True 5.1889863 False
# statute statute NOUN NN pobj xxxx True False
# True 7.4801884 False
# such such ADJ JJ amod xxxx True True
# True 5.4577436 False
# as as SCONJ IN prep xx True True
# True 4.5106106 False
# the the DET DT det xxx True True
# True 4.70935 False
# Land Land PROPN NNP compound Xxxx True False
# True 6.487473 False
# Use Use PROPN NNP compound Xxx True False
# True 5.363257 False
# Act Act PROPN NNP pobj Xxx True False
# True 5.867754 False
# 1978 1978 NUM CD nummod dddd False False
# True 6.031657 False
# , , PUNCT , punct , False False
# True 5.094723 False
# the the DET DT det xxx True True
# True 4.70935 False
# Petroleum Petroleum PROPN NNP compound Xxxxx True False
# True 7.398595 False
# Act Act PROPN NNP pobj Xxx True False
# True 5.867754 False
# 1969 1969 NUM CD npadvmod dddd False False
# True 6.1490893 False
# ( ( PUNCT -LRB- punct ( False False
# True 5.781955 False
# as as SCONJ IN mark xx True True
# True 4.5106106 False
# amended amend VERB VBN relcl xxxx True False
# True 7.215947 False
# ) ) PUNCT -RRB- punct ) False False
# True 5.489806 False
# , , PUNCT , punct , False False
# True 5.094723 False
# Land Land PROPN NNP compound Xxxx True False
# True 6.487473 False
# Title Title PROPN NNP compound Xxxxx True False
# True 6.1329317 False
# Vesting Vesting PROPN NNP compound Xxxxx True False
# True 8.015172 False
# Decree Decree PROPN NNP npadvmod Xxxxx True False
# True 6.7955155 False
# 1993 1993 NUM CD nummod dddd False False
# True 6.2167597 False
# , , PUNCT , punct , False False
# True 5.094723 False
# National National PROPN NNP compound Xxxxx True False
# True 6.4168935 False
# Inland Inland PROPN NNP compound Xxxxx True False
# True 6.350733 False
# Waterways Waterways PROPN NNPS compound Xxxxx True False
# True 7.3388343 False
# Authority Authority PROPN NNP compound Xxxxx True False
# True 6.3641934 False
# Decree Decree PROPN NNP appos Xxxxx True False
# True 6.7955155 False
# 1997 1997 NUM CD nummod dddd False False
# True 6.201739 False
# , , PUNCT , punct , False False
# True 5.094723 False
# the the DET DT det xxx True True
# True 4.70935 False
# Mineral Mineral PROPN NNP compound Xxxxx True False
# True 7.4505687 False
# Act Act PROPN NNP nsubjpass Xxx True False
# True 5.867754 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# others other NOUN NNS conj xxxx True True
# True 4.9988127 False
# have have AUX VBP aux xxxx True True
# True 5.036123 False
# been be AUX VBN auxpass xxxx True True
# True 5.2458506 False
# used use VERB VBN ROOT xxxx True True
# True 5.209864 False
# to to PART TO aux xx True True
# True 4.74484 False
# deprive deprive VERB VB xcomp xxxx True False
# True 5.9506664 False
# the the DET DT det xxx True True
# True 4.70935 False
# Niger Niger PROPN NNP compound Xxxxx True False
# True 7.3060813 False
# Delta Delta PROPN NNP dobj Xxxxx True False
# True 6.704845 False
# of of ADP IN prep xx True True
# True 4.97793 False
# amenities amenity NOUN NNS pobj xxxx True False
# True 7.69295 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# these these DET DT nsubjpass xxxx True True
# True 5.4537206 False
# should should VERB MD aux xxxx True True
# True 5.11326 False
# be be AUX VB auxpass xx True True
# True 4.9934616 False
# abolished abolish VERB VBN conj xxxx True False
# True 6.71667 False
# . . PUNCT . punct . False False
# True 4.9316354 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# Dafinone Dafinone PROPN NNP nsubj Xxxxx True False
# False 0.0 True
# , , PUNCT , punct , False False
# True 5.094723 False
# who who PRON WP nsubj xxx True True
# True 5.7838283 False
# paid pay VERB VBD relcl xxxx True False
# True 6.026424 False
# tributes tribute NOUN NNS dobj xxxx True False
# True 6.4459176 False
# to to ADP IN prep xx True True
# True 4.74484 False
# the the DET DT det xxx True True
# True 4.70935 False
# late late ADJ JJ amod xxxx True False
# True 5.8458853 False
# Chief Chief PROPN NNP compound Xxxxx True False
# True 6.982485 False
# Obafemi Obafemi PROPN NNP compound Xxxxx True False
# False 0.0 True
# Awolowo Awolowo PROPN NNP pobj Xxxxx True False
# False 0.0 True
# , , PUNCT , punct , False False
# True 5.094723 False
# Dr Dr PROPN NNP compound Xx True False
# True 6.625482 False
# Nnamdi Nnamdi PROPN NNP compound Xxxxx True False
# True 7.7878933 False
# Azikiwe Azikiwe PROPN NNP appos Xxxxx True False
# False 0.0 True
# , , PUNCT , punct , False False
# True 5.094723 False
# the the DET DT det xxx True True
# True 4.70935 False
# Sardauna Sardauna PROPN NNP appos Xxxxx True False
# False 0.0 True
# of of ADP IN prep xx True True
# True 4.97793 False
# Sokoto Sokoto PROPN NNP pobj Xxxxx True False
# True 7.845925 False
# , , PUNCT , punct , False False
# True 5.094723 False
# Dr Dr PROPN NNP compound Xx True False
# True 6.625482 False
# Clement Clement PROPN NNP compound Xxxxx True False
# True 6.1713395 False
# Isong Isong PROPN NNP conj Xxxxx True False
# False 0.0 True
# , , PUNCT , punct , False False
# True 5.094723 False
# Chief Chief PROPN NNP compound Xxxxx True False
# True 6.982485 False
# Omo Omo PROPN NNP compound Xxx True False
# True 6.897179 False
# - - PUNCT HYPH punct - False False
# True 5.6033444 False
# Osagie Osagie PROPN NNP conj Xxxxx True False
# False 0.0 True
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# the the DET DT det xxx True True
# True 4.70935 False
# late late ADJ JJ amod xxxx True False
# True 5.8458853 False
# Ken Ken PROPN NNP compound Xxx True False
# True 6.0104184 False
# Saro Saro PROPN NNP compound Xxxx True False
# True 6.7470536 False
# - - PUNCT HYPH punct - False False
# True 5.6033444 False
# Wiva Wiva PROPN NNP conj Xxxx True False
# False 0.0 True
# among among ADP IN prep xxxx True True
# True 5.8330555 False
# others other NOUN NNS pobj xxxx True True
# True 4.9988127 False
# submitted submit VERB VBD ROOT xxxx True False
# True 5.963148 False
# that that SCONJ IN mark xxxx True True
# True 4.8260193 False
# Nigeria Nigeria PROPN NNP nsubjpass Xxxxx True False
# True 6.989754 False
# should should VERB MD aux xxxx True True
# True 5.11326 False
# be be AUX VB auxpass xx True True
# True 4.9934616 False
# restructured restructure VERB VBN ccomp xxxx True False
# True 6.077029 False
# ... ... PUNCT : punct ... False False
# True 5.100429 False
# [ [ PUNCT -LRB- punct [ False False
# True 6.04544 False
# newspaper newspaper NOUN NN compound xxxx True False
# True 7.116756 False
# ellipsis ellipsis NOUN NN ROOT xxxx True False
# True 6.627141 False
# ] ] PUNCT -RRB- punct ] False False
# True 6.0843983 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# that that SCONJ IN mark xxxx True True
# True 4.8260193 False
# the the DET DT det xxx True True
# True 4.70935 False
# time time NOUN NN nsubj xxxx True False
# True 5.1279845 False
# for for ADP IN prep xxx True True
# True 4.8435082 False
# a a DET DT det x True True
# True 5.306696 False
# national national ADJ JJ amod xxxx True False
# True 6.4168935 False
# conference conference NOUN NN pobj xxxx True False
# True 6.6279144 False
# is be AUX VBZ conj xx True True
# True 4.890306 False
# now now ADV RB advmod xxx True True
# True 4.8410244 False
# . . PUNCT . punct . False False
# True 4.9316354 False
# " " PUNCT '' ROOT " False False
# True 5.3378205 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# " " PUNCT `` punct " False False
# True 5.3378205 False
# What what PRON WP dobj Xxxx True True
# True 5.135811 False
# we -PRON- PRON PRP nsubj xx True True
# True 5.260865 False
# thought think VERB VBD advcl xxxx True False
# True 5.0819097 False
# was be AUX VBD ccomp xxx True True
# True 5.4562387 False
# our -PRON- DET PRP$ poss xxx True True
# True 5.592738 False
# black black ADJ JJ amod xxxx True False
# True 6.742908 False
# gold gold NOUN NN nsubj xxxx True False
# True 7.279771 False
# is be AUX VBZ ROOT xx True True
# True 4.890306 False
# today today NOUN NN npadvmod xxxx True False
# True 5.148704 False
# our -PRON- DET PRP$ poss xxx True True
# True 5.592738 False
# black black ADJ JJ amod xxxx True False
# True 6.742908 False
# death death NOUN NN attr xxxx True False
# True 6.604039 False
# ( ( PUNCT -LRB- punct ( False False
# True 5.781955 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# ) ) PUNCT -RRB- punct ) False False
# True 5.489806 False
# the the DET DT det xxx True True
# True 4.70935 False
# stationing stationing NOUN NN nsubj xxxx True False
# True 6.836761 False
# of of ADP IN prep xx True True
# True 4.97793 False
# special special ADJ JJ amod xxxx True False
# True 5.4631042 False
# boats boat NOUN NNS pobj xxxx True False
# True 7.2248573 False
# equipped equip VERB VBN acl xxxx True False
# True 6.5798726 False
# with with ADP IN prep xxxx True True
# True 4.7708583 False
# instruments instrument NOUN NNS pobj xxxx True False
# True 7.225588 False
# for for ADP IN prep xxx True True
# True 4.8435082 False
# mass mass ADJ JJ amod xxxx True False
# True 6.3762555 False
# destruction destruction NOUN NN pobj xxxx True False
# True 6.5104327 False
# to to PART TO aux xx True True
# True 4.74484 False
# police police VERB VB xcomp xxxx True False
# True 7.3889823 False
# our -PRON- DET PRP$ poss xxx True True
# True 5.592738 False
# shore shore NOUN NN dobj xxxx True False
# True 6.2926726 False
# for for ADP IN prep xxx True True
# True 4.8435082 False
# the the DET DT det xxx True True
# True 4.70935 False
# purpose purpose NOUN NN pobj xxxx True False
# True 5.2435203 False
# of of ADP IN prep xx True True
# True 4.97793 False
# oil oil NOUN NN compound xxx True False
# True 7.9124475 False
# exploration exploration NOUN NN pobj xxxx True False
# True 6.6676173 False
# and and CCONJ CC cc xxx True True
# True 4.6577983 False
# the the DET DT det xxx True True
# True 4.70935 False
# exploitation exploitation NOUN NN conj xxxx True False
# True 6.6649384 False
# is be AUX VBZ ccomp xx True True
# True 4.890306 False
# not not PART RB neg xxx True True
# True 4.9436083 False
# the the DET DT det xxx True True
# True 4.70935 False
# answer answer NOUN NN attr xxxx True False
# True 5.464643 False
# " " PUNCT '' punct " False False
# True 5.3378205 False
# he -PRON- PRON PRP nsubj xx True True
# True 6.080851 False
# observed observe VERB VBD ROOT xxxx True False
# True 6.0083275 False
# ... ... PUNCT : punct ... False False
# True 5.100429 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# Source source NOUN NN ROOT Xxxxx True False
# True 6.095233 False
# : : PUNCT : punct : False False
# True 5.474056 False
# The the DET DT det Xxx True True
# True 4.70935 False
# Guardian Guardian PROPN NNP compound Xxxxx True False
# True 6.2794085 False
# web web NOUN NN compound xxx True False
# True 6.444398 False
# site site NOUN NN ROOT xxxx True False
# True 6.315663 False
# , , PUNCT , punct , False False
# True 5.094723 False
# Lagos Lagos PROPN NNP appos Xxxxx True False
# True 7.0656667 False
# , , PUNCT , punct , False False
# True 5.094723 False
# in in ADP IN prep xx True True
# True 5.0929856 False
# English English PROPN NNP pobj Xxxxx True False
# True 6.98872 False
# 20 20 NUM CD punct dd False False
# True 5.2563577 False
# Oct Oct PROPN NNP npadvmod Xxx True False
# True 5.5206485 False
# 01 01 NUM CD nummod dd False False
# True 6.6961136 False
#   SPACE _SP   False False
# False 0.0 True
# BBC BBC PROPN NNP compound XXX True False
# True 6.6346407 False
# Mon Mon PROPN NNP compound Xxx True False
# True 6.74068 False
# AF1 AF1 PROPN NNP compound XXd False False
# True 8.465216 False
# AFEauwaf AFEauwaf PROPN NNP ROOT XXXxxxx True False
# False 0.0 True
# 211001 211001 NUM CD nummod dddd False False
# False 0.0 True
# / / SYM SYM punct / False False
# True 5.9076996 False
# cnob cnob NOUN NN ROOT xxxx True False
# False 0.0 True
#
#
#  SPACE _SP
#  False False
# False 0.0 True
# © © PROPN NNP compound © False False
# True 6.794782 False
# British British PROPN NNP compound Xxxxx True False
# True 6.5735483 False
# Broadcasting Broadcasting PROPN NNP compound Xxxxx True False
# True 6.511486 False
# Corporation Corporation PROPN NNP ROOT Xxxxx True False
# True 6.53554 False
# 2001 2001 NUM CD nummod dddd False False
# True 6.0808115 False
#
#
#   SPACE _SP
#   False False
# False 0.0 True
# HYPERLINK HYPERLINK PROPN NNP nmod XXXX True False
# True 6.3854785 False
# " " PUNCT `` punct " False False
# True 5.3378205 False
# http://www.bbcmonitoringonline.com/mmu?page=77&action=view&item=0&srchid=0025mzh&sw=1 http://www.bbcmonitoringonline.com/mmu?page=77&action=view&item=0&srchid=0025mzh&sw=1 PROPN NNP nmod xxxx://xxx.xxxx.xxx/xxx?xxxx=dd&xxxx=xxxx&xxxx=d&xxxx=ddddxxx&xx=d False False
# False 0.0 True
# " " PUNCT '' punct " False False
# True 5.3378205 False
# \l \l NOUN NN nmod \x False False
# False 0.0 True
# " " PUNCT `` punct " False False
# True 5.3378205 False
# TOP top NOUN NN nmod XXX True True
# True 5.5138364 False
# " " PUNCT '' punct " False False
# True 5.3378205 False
# Top top NOUN NN ROOT Xxx True True
# True 5.5138364 False
#
#
#  SPACE _SP
#  False False
# False 0.0 True

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Nigeria 0 7 GPE
# Pan-Niger Delta 9 24 NORP
# Akpa Esajere 93 105 PERSON
# Federalism Tops Talks 117 138 WORK_OF_ART
# Pan-Niger 142 151 NORP
# Nigerian 186 194 NORP
# Guardian 209 217 ORG
# 20 October 230 240 DATE
# 100 per cent 309 321 MONEY
# yesterday 427 436 DATE
# first 444 449 ORDINAL
# Pan-Niger Delta 450 465 ORG
# Calabar 518 525 GPE
# Expectedly 527 537 ORDINAL
# University of Calabar 614 635 ORG
# 100 per cent 740 752 MONEY
# six 828 831 CARDINAL
# the First Republic 878 896 GPE
# Ethnic Nationality Forum 911 935 ORG
# the Niger Delta Area 940 960 LOC
# David Dafinone 967 981 PERSON
# 100 per cent 1078 1090 MONEY
# Cross River 1561 1572 LOC
# Donald Duke 1582 1593 PERSON
# Tony Momoh 1623 1633 PERSON
# Bayelsa Traditional Rulers 1647 1673 ORG
# Raph Iwowari Mein VII 1689 1710 PERSON
# Margaret Ekpo 1746 1759 PERSON
# OMPADEC 1780 1787 ORG
# Albert Horsfall 1794 1809 PERSON
# Federal House of Representative 1819 1850 ORG
# Nduese Essien 1857 1870 PERSON
# ECOMOG 1879 1885 ORG
# Maj-Gen Felix Mujakper 1896 1918 PERSON
# First 1920 1925 ORDINAL
# Mfio Akobo 1951 1961 PERSON
# Willie Okowa 1973 1985 PERSON
# Bishop Uses 1987 1998 PERSON
# Ikot Ekpene Diocese 2002 2021 ORG
# Dafinone 2104 2112 ORG
# the Niger Delta 2119 2134 LOC
# the years 2183 2192 DATE
# first 2706 2711 ORDINAL
# four 2728 2732 CARDINAL
# all-season 2742 2752 DATE
# Benin 2763 2768 GPE
# Akwa Ibom 2772 2781 GPE
# the Land Use Act 1978 2908 2929 LAW
# the Petroleum Act 1969 2931 2953 LAW
# Land Title Vesting Decree 2968 2993 LAW
# 1993 2994 2998 DATE
# National Inland Waterways Authority 3000 3035 ORG
# 1997 3043 3047 DATE
# the Mineral Act 3049 3064 LAW
# the Niger Delta 3102 3117 LOC
# Dafinone 3162 3170 ORG
# Obafemi Awolowo 3208 3223 PERSON
# Nnamdi Azikiwe 3228 3242 PERSON
# Sardauna 3248 3256 PERSON
# Sokoto 3260 3266 GPE
# Clement Isong 3271 3284 PERSON
# Omo-Osagie 3292 3302 PERSON
# Ken Saro-Wiva 3316 3329 PERSON
# Nigeria 3358 3365 GPE
# today 3505 3510 DATE
# Guardian 3736 3744 ORG
# Lagos 3755 3760 GPE
# English 3765 3772 LANGUAGE
# 20 Oct 01 3773 3784 DATE
# BBC 3784 3787 ORG
# © British Broadcasting Corporation 3818 3852 ORG
# 2001 3853 3857 DATE

# %%
texts = [
    "Net income was $9.4 million compared to the prior year of $2.7 million.",
    "Revenue exceeded twelve billion dollars, with a loss of $1b.",
]

nlp = spacy.load("en_core_web_sm")
for doc in nlp.pipe(texts, disable=["tagger", "parser"]):
    # Do something with the doc here
    print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# [('$9.4 million', 'MONEY'), ('the prior year', 'DATE'), ('$2.7 million', 'MONEY')]
# [('twelve billion dollars', 'MONEY'), ('1b', 'MONEY')]
